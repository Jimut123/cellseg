# %%
import json
import matplotlib.pyplot as plt
with open('history_classification_model_v2_150e.json', 'r') as f:
    history = json.load(f)
print (len(history))
# Out:
# In /home/akshartamal/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.unicode rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In /home/akshartamal/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The savefig.frameon rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/akshartamal/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The pgf.debug rcparam was deprecated in Matplotlib 3.0 and will be removed in 3.2.
# In /home/akshartamal/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The verbose.level rcparam was deprecated in Matplotlib 3.1 and will be removed in 3.3.
# In /home/akshartamal/anaconda3/lib/python3.7/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# ...

# %%
for item in history:
    print(item)
# Out:
# loss
# accuracy
# auc
# precision
# recall
# true_positives
# true_negatives
# false_positives
# false_negatives
# val_loss
# val_accuracy
# val_auc
# val_precision
# val_recall
# val_true_positives
# val_true_negatives
# val_false_positives
# val_false_negatives
# lr

# %%
# accuracy = []
# for item in history['true_positives']:
#     accuracy.append(history['true_positives'][item])

# val_accuracy = []
# for item in history['val_true_positives']:
#     val_accuracy.append(history['val_true_positives'][item])

# plt.figure(figsize=(12,6))
# plt.title('True Positives', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
# plt.plot(accuracy,color='blue', linewidth = 3.0)
# plt.plot(val_accuracy,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
# plt.xticks(fontsize=20)
# plt.yticks(fontsize=20)
# #plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
# lgd = plt.legend(['True Positives','Validation True Positives'],loc="lower right",
#           prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.44, 0.77))
# plt.savefig('true_positives.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# plt.savefig('true_positives.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')

# %%
accuracy = []
for item in history['recall']:
    accuracy.append(history['recall'][item])

val_accuracy = []
for item in history['val_recall']:
    val_accuracy.append(history['val_recall'][item])

plt.figure(figsize=(12,6))
plt.title('Recall', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(accuracy,color='blue', linewidth = 3.0)
plt.plot(val_accuracy,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['Recall','Validation Recall'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.44, 0.77))
plt.savefig('recall.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('recall.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
accuracy = []
for item in history['precision']:
    accuracy.append(history['precision'][item])

val_accuracy = []
for item in history['val_precision']:
    val_accuracy.append(history['val_precision'][item])

plt.figure(figsize=(12,6))
plt.title('Precision', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(accuracy,color='blue', linewidth = 3.0)
plt.plot(val_accuracy,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['precision','Validation precision'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.44, 0.77))
plt.savefig('precision.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('precision.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
accuracy = []
for item in history['auc']:
    accuracy.append(history['auc'][item])

val_accuracy = []
for item in history['val_auc']:
    val_accuracy.append(history['val_auc'][item])

plt.figure(figsize=(12,6))
plt.title('AUC', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(accuracy,color='blue', linewidth = 3.0)
plt.plot(val_accuracy,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['AUC','Validation AUC'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.44, 0.77))
plt.savefig('AUC.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('AUC.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
accuracy = []
for item in history['accuracy']:
    accuracy.append(history['accuracy'][item])

val_accuracy = []
for item in history['val_accuracy']:
    val_accuracy.append(history['val_accuracy'][item])

plt.figure(figsize=(12,6))
plt.title('Accuracy', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(accuracy,color='blue', linewidth = 3.0)
plt.plot(val_accuracy,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['Accuracy','Validation Accuracy'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.44, 0.77))
plt.savefig('Accuracy.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('Accuracy.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
loss = []
for item in history['loss']:
    loss.append(history['loss'][item])

val_loss = []
for item in history['val_loss']:
    val_loss.append(history['val_loss'][item])

plt.figure(figsize=(12,6))
plt.title('Loss', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(loss,color='blue', linewidth = 3.0)
plt.plot(val_loss,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['Loss','Validation Loss'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.37, 0.77))
plt.savefig('Loss.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('Loss.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
lr = []
for item in history['lr']:
    lr.append(history['lr'][item])


plt.figure(figsize=(12,6))
plt.title('Learning Rate', fontsize=20, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(lr,color='green', linewidth = 3.0)
# plt.plot(val_loss,color='orange', linestyle = '-.', dashes=(5, 1), linewidth = 3.0)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
#plt.legend(['AttnR2Unet','R2Unet','AttnUnet','MultiResUnet','Mod UNet','UNet', 'Proposed Attn 1'],loc="lower right")
lgd = plt.legend(['Learning Rate'],loc="lower right",
          prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.35, 0.86))
plt.savefig('Learning_rate.eps',  bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('Learning_rate.png',  bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
