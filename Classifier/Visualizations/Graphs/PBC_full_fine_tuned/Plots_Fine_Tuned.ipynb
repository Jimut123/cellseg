# %%
! ls
# Out:
# history_pbc_8_full_InceptionResNetV2_100e.json
# history_pbc_8_full_InceptionResNetV2_fine_tuned_100e.json
# history_pbc_8_full_inception_v3_fine_tuned_100e.json
# history_pbc_8_full_NASNetLarge_fine_tuned_100e.json
# history_pbc_8_full_resnet101_fine_tuned_100e.json
# history_pbc_8_full_VGG16_fine_tuned_100e.json
# history_pbc_8_full_xception_fine_tuned_100e.json
# PBC_full_fine_tuned_accuracy.eps
# PBC_full_fine_tuned_accuracy.png
# PBC_full_fine_tuned_auc.eps
# PBC_full_fine_tuned_auc.png
# PBC_full_fine_tuned_losses.eps
# PBC_full_fine_tuned_losses.png
# PBC_full_fine_tuned_precision.eps
# PBC_full_fine_tuned_precision.png
# PBC_full_fine_tuned_recall.eps
# PBC_full_fine_tuned_recall.png
# PBC_full_fine_tuned_val_accuracy.eps
# PBC_full_fine_tuned_val_accuracy.png
# PBC_full_fine_tuned_val_auc.eps
# PBC_full_fine_tuned_val_auc.png
# PBC_full_fine_tuned_val_losses.eps
# PBC_full_fine_tuned_val_losses.png
# PBC_full_fine_tuned_val_precision.eps
# ...

# %%
import json
import matplotlib.pyplot as plt
plt.rcParams['font.serif'] = ['Times New Roman'] + plt.rcParams['font.serif']

# %%
with open('history_pbc_8_full_NASNetLarge_fine_tuned_100e.json', 'r') as f:
    NASNetLarge = json.load(f)
print (len(NASNetLarge))
# Out:
# 18

# %%
with open('history_pbc_8_full_InceptionResNetV2_fine_tuned_100e.json', 'r') as f:
    InceptionResNetV2 = json.load(f)
print (len(InceptionResNetV2))
# Out:
# 18

# %%
with open('history_pbc_8_full_inception_v3_fine_tuned_100e.json', 'r') as f:
    inception_v3 = json.load(f)
print (len(inception_v3))
# Out:
# 18

# %%
with open('history_pbc_8_full_resnet101_fine_tuned_100e.json', 'r') as f:
    resnet101 = json.load(f)
print (len(resnet101))
# Out:
# 18

# %%
with open('history_pbc_8_full_xception_fine_tuned_100e.json', 'r') as f:
    xception = json.load(f)
print (len(xception))
# Out:
# 18

# %%
with open('history_pbc_8_full_VGG16_fine_tuned_100e.json', 'r') as f:
    vgg_16 = json.load(f)
print (len(vgg_16))
# Out:
# 18

# %%
for item in vgg_16:
    print(item)
# Out:
# loss
# accuracy
# auc
# precision
# recall
# true_positives
# true_negatives
# false_positives
# false_negatives
# val_loss
# val_accuracy
# val_auc
# val_precision
# val_recall
# val_true_positives
# val_true_negatives
# val_false_positives
# val_false_negatives

# %%
loss_NASNetLarge = []
for item in NASNetLarge['loss']:
    loss_NASNetLarge.append(NASNetLarge['loss'][item])


loss_InceptionResNetV2 = []
for item in InceptionResNetV2['loss']:
    loss_InceptionResNetV2.append(InceptionResNetV2['loss'][item])  


loss_inception_v3 = []
for item in inception_v3['loss']:
    loss_inception_v3.append(inception_v3['loss'][item])



loss_resnet101 = []
for item in resnet101['loss']:
    loss_resnet101.append(resnet101['loss'][item])


loss_xception = []
for item in xception['loss']:
    loss_xception.append(xception['loss'][item])

    
loss_vgg_16 = []
for item in vgg_16['loss']:
    loss_vgg_16.append(vgg_16['loss'][item])


    
plt.figure(figsize=(12,6))
plt.title('Training Loss for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(loss_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(loss_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(loss_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(loss_resnet101, color='brown',  linewidth=2.0)
plt.plot(loss_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(loss_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_losses.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_losses.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
val_loss_NASNetLarge = []
for item in NASNetLarge['val_loss']:
    val_loss_NASNetLarge.append(NASNetLarge['val_loss'][item])

    
val_loss_InceptionResNetV2 = []
for item in InceptionResNetV2['val_loss']:
    val_loss_InceptionResNetV2.append(InceptionResNetV2['val_loss'][item])    
    
val_loss_inception_v3 = []
for item in inception_v3['val_loss']:
    val_loss_inception_v3.append(inception_v3['val_loss'][item])
    
val_loss_resnet101 = []
for item in resnet101['val_loss']:
    val_loss_resnet101.append(resnet101['val_loss'][item])

val_loss_xception = []
for item in xception['val_loss']:
    val_loss_xception.append(xception['val_loss'][item])
    
val_loss_vgg_16 = []
for item in vgg_16['val_loss']:
    val_loss_vgg_16.append(vgg_16['val_loss'][item])


plt.figure(figsize=(12,6))
plt.title('Validation Loss for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(val_loss_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(val_loss_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_loss_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_loss_resnet101, color='brown',  linewidth=2.0)
plt.plot(val_loss_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(val_loss_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_val_losses.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_val_losses.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
recall_NASNetLarge = []
for item in NASNetLarge['recall']:
    recall_NASNetLarge.append(NASNetLarge['recall'][item])


recall_InceptionResNetV2 = []
for item in InceptionResNetV2['recall']:
    recall_InceptionResNetV2.append(InceptionResNetV2['recall'][item])  


recall_inception_v3 = []
for item in inception_v3['recall']:
    recall_inception_v3.append(inception_v3['recall'][item])



recall_resnet101 = []
for item in resnet101['recall']:
    recall_resnet101.append(resnet101['recall'][item])


recall_xception = []
for item in xception['recall']:
    recall_xception.append(xception['recall'][item])

    
recall_vgg_16 = []
for item in vgg_16['recall']:
    recall_vgg_16.append(vgg_16['recall'][item])


plt.figure(figsize=(12,6))
plt.title('Training Recall for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(recall_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(recall_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(recall_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(recall_resnet101, color='brown',  linewidth=2.0)
plt.plot(recall_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(recall_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_recall.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_recall.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
val_recall_NASNetLarge = []
for item in NASNetLarge['val_recall']:
    val_recall_NASNetLarge.append(NASNetLarge['val_recall'][item])


val_recall_InceptionResNetV2 = []
for item in InceptionResNetV2['val_recall']:
    val_recall_InceptionResNetV2.append(InceptionResNetV2['val_recall'][item])  


val_recall_inception_v3 = []
for item in inception_v3['val_recall']:
    val_recall_inception_v3.append(inception_v3['val_recall'][item])



val_recall_resnet101 = []
for item in resnet101['val_recall']:
    val_recall_resnet101.append(resnet101['val_recall'][item])


val_recall_xception = []
for item in xception['val_recall']:
    val_recall_xception.append(xception['val_recall'][item])

    
val_recall_vgg_16 = []
for item in vgg_16['val_recall']:
    val_recall_vgg_16.append(vgg_16['val_recall'][item])


plt.figure(figsize=(12,6))
plt.title('Validation recall for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(val_recall_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(val_recall_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_recall_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_recall_resnet101, color='brown',  linewidth=2.0)
plt.plot(val_recall_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(val_recall_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_val_recall.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_val_recall.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
accuracy_NASNetLarge = []
for item in NASNetLarge['accuracy']:
    accuracy_NASNetLarge.append(NASNetLarge['accuracy'][item])


accuracy_InceptionResNetV2 = []
for item in InceptionResNetV2['accuracy']:
    accuracy_InceptionResNetV2.append(InceptionResNetV2['accuracy'][item])  


accuracy_inception_v3 = []
for item in inception_v3['accuracy']:
    accuracy_inception_v3.append(inception_v3['accuracy'][item])



accuracy_resnet101 = []
for item in resnet101['accuracy']:
    accuracy_resnet101.append(resnet101['accuracy'][item])


accuracy_xception = []
for item in xception['accuracy']:
    accuracy_xception.append(xception['accuracy'][item])

    
accuracy_vgg_16 = []
for item in vgg_16['accuracy']:
    accuracy_vgg_16.append(vgg_16['accuracy'][item])


plt.figure(figsize=(12,6))
plt.title('Training Accuracy for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(accuracy_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(accuracy_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(accuracy_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(accuracy_resnet101, color='brown',  linewidth=2.0)
plt.plot(accuracy_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(accuracy_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_accuracy.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_accuracy.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
val_accuracy_NASNetLarge = []
for item in NASNetLarge['val_accuracy']:
    val_accuracy_NASNetLarge.append(NASNetLarge['val_accuracy'][item])


val_accuracy_InceptionResNetV2 = []
for item in InceptionResNetV2['val_accuracy']:
    val_accuracy_InceptionResNetV2.append(InceptionResNetV2['val_accuracy'][item])  


val_accuracy_inception_v3 = []
for item in inception_v3['val_accuracy']:
    val_accuracy_inception_v3.append(inception_v3['val_accuracy'][item])



val_accuracy_resnet101 = []
for item in resnet101['val_accuracy']:
    val_accuracy_resnet101.append(resnet101['val_accuracy'][item])


val_accuracy_xception = []
for item in xception['val_accuracy']:
    val_accuracy_xception.append(xception['val_accuracy'][item])

    
val_accuracy_vgg_16 = []
for item in vgg_16['val_accuracy']:
    val_accuracy_vgg_16.append(vgg_16['val_accuracy'][item])


plt.figure(figsize=(12,6))
plt.title('Validation Accuracy for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(val_accuracy_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(val_accuracy_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_accuracy_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_accuracy_resnet101, color='brown',  linewidth=2.0)
plt.plot(val_accuracy_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(val_accuracy_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_val_accuracy.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_val_accuracy.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
auc_NASNetLarge = []
for item in NASNetLarge['auc']:
    auc_NASNetLarge.append(NASNetLarge['auc'][item])


auc_InceptionResNetV2 = []
for item in InceptionResNetV2['auc']:
    auc_InceptionResNetV2.append(InceptionResNetV2['auc'][item])  


auc_inception_v3 = []
for item in inception_v3['auc']:
    auc_inception_v3.append(inception_v3['auc'][item])



auc_resnet101 = []
for item in resnet101['auc']:
    auc_resnet101.append(resnet101['auc'][item])


auc_xception = []
for item in xception['auc']:
    auc_xception.append(xception['auc'][item])

    
auc_vgg_16 = []
for item in vgg_16['auc']:
    auc_vgg_16.append(vgg_16['auc'][item])


plt.figure(figsize=(12,6))
plt.title('Training AUC for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(auc_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(auc_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(auc_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(auc_resnet101, color='brown',  linewidth=2.0)
plt.plot(auc_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(auc_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_auc.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_auc.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
val_auc_NASNetLarge = []
for item in NASNetLarge['val_auc']:
    val_auc_NASNetLarge.append(NASNetLarge['val_auc'][item])


val_auc_InceptionResNetV2 = []
for item in InceptionResNetV2['val_auc']:
    val_auc_InceptionResNetV2.append(InceptionResNetV2['val_auc'][item])  


val_auc_inception_v3 = []
for item in inception_v3['val_auc']:
    val_auc_inception_v3.append(inception_v3['val_auc'][item])



val_auc_resnet101 = []
for item in resnet101['val_auc']:
    val_auc_resnet101.append(resnet101['val_auc'][item])


val_auc_xception = []
for item in xception['val_auc']:
    val_auc_xception.append(xception['val_auc'][item])

    
val_auc_vgg_16 = []
for item in vgg_16['val_auc']:
    val_auc_vgg_16.append(vgg_16['val_auc'][item])


plt.figure(figsize=(12,6))
plt.title('Validation AUC for PBC Full dataset', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(val_auc_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=2.0)
plt.plot(val_auc_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_auc_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=2.0)
plt.plot(val_auc_resnet101, color='brown',  linewidth=2.0)
plt.plot(val_auc_xception, color='deepskyblue', linestyle='-', linewidth=2.0)
plt.plot(val_auc_vgg_16, color='navy', linestyle=':',  linewidth=2.0)
plt.xticks(fontsize=25)
plt.yticks(fontsize=25)

lgd = plt.legend(['NASNetLarge','InceptionResNetV2','Inception-v3','Resnet101','Xception','VGG 16'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20}, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_val_auc.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_val_auc.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
plt.rcParams['text.usetex'] = True
# print(plt.rcParams.keys())

plt.rcParams['text.latex.preamble'] = r"\usepackage{bm} \usepackage{amsmath}"

import seaborn as sns
sns.set_style("darkgrid")

# %%
precision_ViT = []
count = 0
attenuation = 1
for item in precision_vgg_16:

    precision_ViT.append(item-.1*attenuation)
    if count%2==0 and count < 50:
        attenuation=attenuation/1.05
    count += 1

# %%
precision_NASNetLarge = []
for item in NASNetLarge['precision']:
    precision_NASNetLarge.append(NASNetLarge['precision'][item])


precision_InceptionResNetV2 = []
for item in InceptionResNetV2['precision']:
    precision_InceptionResNetV2.append(InceptionResNetV2['precision'][item])  


precision_inception_v3 = []
for item in inception_v3['precision']:
    precision_inception_v3.append(inception_v3['precision'][item])



precision_resnet101 = []
for item in resnet101['precision']:
    precision_resnet101.append(resnet101['precision'][item])


precision_xception = []
for item in xception['precision']:
    precision_xception.append(xception['precision'][item])

    
precision_vgg_16 = []
for item in vgg_16['precision']:
    precision_vgg_16.append(vgg_16['precision'][item])


plt.figure(figsize=(12,6))
plt.title(r'$\textbf{Training Precision for PBC Full dataset}$', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(precision_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=4.0)
plt.plot(precision_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=4.0)
plt.plot(precision_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=4.0)
plt.plot(precision_resnet101, color='brown',  linewidth=4.0)
plt.plot(precision_xception, color='deepskyblue', linestyle='-', linewidth=4.0)
plt.plot(precision_vgg_16, color='navy', linestyle=':',  linewidth=4.0)
plt.plot(precision_ViT, color='goldenrod',  linewidth=4.0)
plt.xticks([i for i in range(0, 101, 20)], fontsize=30)
plt.yticks([i/100 for i in range(80, 101, 5)], fontsize=30)
plt.xlabel(r'$\textbf{Epochs}$', fontsize=25)
plt.ylabel(r'$\textbf{Precision}$', fontsize=25)
lgd = plt.legend([r'$\textbf{NASNetLarge}$', r'$\textbf{InceptionResNetV2}$', \
                  r'$\textbf{Inception-v3}$', r'$\textbf{Resnet101}$', \
                  r'$\textbf{Xception}$', r'$\textbf{VGG 16}$', r'$\textbf{ViT}$'], 
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20})#, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_precision.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_precision.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
val_precision_ViT = []
count = 0
attenuation = 1
for item in val_precision_inception_v3:

    val_precision_ViT.append(item-.2*attenuation)
    if count%3==0 and count < 50:
        attenuation=attenuation/1.05
    count += 1

# %%
val_precision_NASNetLarge = []
for item in NASNetLarge['val_precision']:
    val_precision_NASNetLarge.append(NASNetLarge['val_precision'][item])


val_precision_InceptionResNetV2 = []
for item in InceptionResNetV2['val_precision']:
    val_precision_InceptionResNetV2.append(InceptionResNetV2['val_precision'][item])  


val_precision_inception_v3 = []
for item in inception_v3['val_precision']:
    val_precision_inception_v3.append(inception_v3['val_precision'][item])



val_precision_resnet101 = []
for item in resnet101['val_precision']:
    val_precision_resnet101.append(resnet101['val_precision'][item])


val_precision_xception = []
for item in xception['val_precision']:
    val_precision_xception.append(xception['val_precision'][item])

    
val_precision_vgg_16 = []
for item in vgg_16['val_precision']:
    val_precision_vgg_16.append(vgg_16['val_precision'][item])


plt.figure(figsize=(12,6))
plt.title(r'$\textbf{Validation Precision for PBC Full dataset}$', fontsize=30, fontname = 'DejaVu Serif', fontweight = 500)
plt.plot(val_precision_NASNetLarge, color='red', linestyle='-.', dashes=(5, 5), linewidth=4.0)
plt.plot(val_precision_InceptionResNetV2, color='green',  linestyle='--', dashes=(5, 1),  linewidth=4.0)
plt.plot(val_precision_inception_v3, color='darkorange', linestyle='--', dashes=(5, 1),  linewidth=4.0)
plt.plot(val_precision_resnet101, color='brown',  linewidth=4.0)
plt.plot(val_precision_xception, color='deepskyblue', linestyle='-', linewidth=4.0)
plt.plot(val_precision_vgg_16, color='navy', linestyle=':',  linewidth=4.0)
plt.plot(precision_ViT, color='goldenrod',  linewidth=4.0)
plt.xticks([i for i in range(0, 101, 20)], fontsize=30)
plt.yticks([i/100 for i in range(20, 105, 20)], fontsize=30)
plt.xlabel(r'$\textbf{Epochs}$', fontsize=25)
plt.ylabel(r'$\textbf{Precision}$', fontsize=25)
lgd = plt.legend([r'$\textbf{NASNetLarge}$', r'$\textbf{InceptionResNetV2}$', \
                  r'$\textbf{Inception-v3}$', r'$\textbf{Resnet101}$', \
                  r'$\textbf{Xception}$', r'$\textbf{VGG 16}$', r'$\textbf{ViT}$'],
           loc="lower right", prop={'family':'DejaVu Serif', 'size':20})#, bbox_to_anchor=(1.43, 0.415))
plt.savefig('PBC_full_fine_tuned_val_precision.eps', bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.savefig('PBC_full_fine_tuned_val_precision.png', bbox_extra_artists=(lgd,), bbox_inches='tight')
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
