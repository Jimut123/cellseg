# %%
"""

 
"""

# %%
import numpy as np
import seaborn as sns
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

y = [592, 1015, 1137, 1214, 1218, 1420, 3117, 3329]
x = [1,2,3,4,5,6,7,8]
labels = ['PROMYELOCYTES', 'METAMYELOCYTE', 'MYELOCYTE', 'LYMPHOCYTES', 'BASOPHILS', 'MONOCYTES', 'EOSINOPHILS', 'NEUTROPHILS']
clrs = [ 'lime', 'lime', 'lime', 'lightseagreen', 'hotpink', 'gold', 'cornflowerblue', 'orangered']

# %%
#sns.color_palette("Dark2")
plt.figure(figsize=(15,8))
ax = sns.barplot(x=y, y=labels,palette=clrs).set_title('No. of IN PBC DA dataset',\
                                        fontsize=40,fontname = 'DejaVu Serif', fontweight = 500)
plt.xticks([i for i in range(0,3501,500)],fontsize=30, fontname = 'DejaVu Serif')
plt.yticks(fontsize=30, fontname = 'DejaVu Serif')
#ax.set_xticklabels(labels, rotation=30 );
# ax.set_xlabel(fontsize=20)
# ax.set_ylabel(fontsize=20)
plt.savefig('pbc_da_dist.eps',bbox_inches='tight')
plt.savefig('pbc_da_dist.png',bbox_inches='tight')
plt.show()
